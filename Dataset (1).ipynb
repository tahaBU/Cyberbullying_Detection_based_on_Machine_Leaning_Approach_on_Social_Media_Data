# %%
# !pip install snscrape
import pandas as pd
import snscrape.modules.twitter as sntwitter
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 KB 2.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
query1 = "(dumbfanficmoments OR nba OR itkillsmewhenpeople OR thingsthatgetmeupset OR twograves OR amalayer OR 1lawan1 OR ripcourtney OR dogs OR makeachange OR rude OR itdoesnotmakeyoucool OR tomyfutureson OR tuite10pessoasbonitas OR tvo OR debate2012 OR sex OR pets OR p2b OR hot OR justsayin OR fuckyou OR  suck OR rude OR black OR pussy OR sex OR negro OR puppy OR  LGBTQ OR  hypocrites OR  honesty  OR Whore OR dog OR france) lang:en until:2023-03-03 since:2015-01-01" 
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query1).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query1.csv')

query2 = "( share OR obese OR standup OR debates OR savealife OR bully OR bullies OR istopbullying OR brave OR in8thgrade OR bullyingisforlosers OR stopbullying OR bullyingé OR impactlive OR glee OR anonymous OR tcot OR mentionke OR banbeliebers) lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query2).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query2.csv')


query3 = "(auspol OR saynotobullying OR dt OR bullymovie OR education OR moms OR eating OR hypocrite OR pathetic OR spiritday OR uk OR edchat OR r OR nobodylikes OR neverwouldiever OR ripamandatodd) lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query3).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query3.csv')

query4 = "( greysonfact OR lgbt OR cyberbullyingiswrong OR cdnpoli OR bornbravebus OR 30thingsaboutme OR karma OR bullied OR ripdemizadirectioner OR wheniwaslittle OR childabuse OR s OR whydoyouthinkitsokayto OR teamfollowback OR 1dfact OR gop OR sorrynotsorry) lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query4).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query4.csv')

query5 = "( xfactor OR obesity OR ripamanda OR no OR pitbull OR pinkshirtday OR gangupforgood OR health OR sad OR wwe OR fridayfightagainst OR mean OR ff OR amandatodd OR school OR bullyingisnothot OR bgc9 OR iwanttopunchpeoplewho OR antibullying OR growup) lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query5).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query5.csv')

query6 = "(ripmegan OR stopbullyingnow OR ripboybeliebermartin OR capricorn OR suicide OR itsnotokayto OR schools OR 100thingsihate OR rt OR ifihadthepower OR truth OR nw OR porn OR englishbulldog OR libra OR kids OR twitition OR dads OR wtf OR típicodegordos) lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query6).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query6.csv')
# Out:
# <ipython-input-3-c638f73d89be>:8: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-3-c638f73d89be>:8: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-3-c638f73d89be>:19: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-3-c638f73d89be>:19: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-3-c638f73d89be>:31: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-3-c638f73d89be>:31: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
# ...

# %% [markdown]
# # **Non B**

# %%
query = "lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 30000
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/tweetData.csv')
# Out:
# <ipython-input-4-16d58bf92152>:8: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-4-16d58bf92152>:8: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])

# %% [markdown]
# # **combined**

# %%
query1 = pd.read_csv('/content/drive/MyDrive/Dataset/query1.csv')
query3 = pd.read_csv('/content/drive/MyDrive/Dataset/query3.csv')

# %%
query13 = pd.concat([query1,query3], axis = 0)

# %%
query4 = pd.read_csv('/content/drive/MyDrive/Dataset/query4.csv')
query5 = pd.read_csv('/content/drive/MyDrive/Dataset/query5.csv')

# %%
query45 = pd.concat([query4,query5], axis = 0)

# %%
query6 = pd.read_csv('/content/drive/MyDrive/Dataset/query6.csv')

# %%
query1345 = pd.concat([query13,query45], axis = 0)

# %%
query13456 = pd.concat([query1345,query6], axis = 0)

# %%
cyberbullyingalldata  = query13456.loc[:, ~query13456.columns.str.contains('^Unnamed')]
cyberbullyingalldata.to_csv('/content/drive/MyDrive/Dataset/cyberbullyingalldata.csv')

# %%
data1 = pd.read_csv('/content/drive/MyDrive/Dataset/cyberbullyingalldata.csv')
data1.tail(5)
# Out:
#        Unnamed: 0                       Date             User  \
# 24995        4995  2023-03-02 23:47:26+00:00       sm23342426
# 24996        4996  2023-03-02 23:47:26+00:00    WaterChicken2
# 24997        4997  2023-03-02 23:47:26+00:00  5FeetOf_KickAss
# 24998        4998  2023-03-02 23:47:26+00:00    NickiSelAri17
# 24999        4999  2023-03-02 23:47:25+00:00     8foottallman
#
#                                                    Tweet
# 24995  @RepJamesComer @MariaBartiromo We all know you...
# 24996  @MrStevenSteele @KaizokuRogue @EdKrassen Steve...
# 24997  That Celsius will have you so gassy bruh like ...
# 24998  @WantSomeOnika_ Wtf happened to queen radio?!?!?!
# 24999              @simmevision wait was this recent wtf

# %%
data1.shape
# Out:
# (25000, 4)

# %%
data2 = pd.read_csv('/content/drive/MyDrive/Dataset/tweetData.csv')
data2.tail(5)
# Out:
#       Unnamed: 0                       Date           User  \
# 30002      29995  2023-03-02 23:58:53+00:00  PaulMcAuley88
# 30003      29996  2023-03-02 23:58:53+00:00       _DaKid11
# 30004      29997  2023-03-02 23:58:53+00:00    CarlaCrotty
# 30005      29998  2023-03-02 23:58:53+00:00         gzyszn
# 30006      29999  2023-03-02 23:58:53+00:00        Ahziiii
#
#                                                 Tweet
# 30002             @jordanbpeterson Milk n two big man
# 30003         When I Think About My Past I Get Chills
# 30004          #AlexMurdaugh verdict being read soon.
# 30005                  Python framework is killing me
# 30006  baby while we’re young we should just have fun

# %%
data2.shape
# Out:
# (30007, 4)
