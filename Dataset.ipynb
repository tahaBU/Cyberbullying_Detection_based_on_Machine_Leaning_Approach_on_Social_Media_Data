# %%
# !pip install snscrape
import pandas as pd
import snscrape.modules.twitter as sntwitter
import snscrape.modules.twitter as sntwitter
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
query1 = "(dumbfanficmoments OR nba OR itkillsmewhenpeople OR thingsthatgetmeupset OR twograves OR amalayer OR 1lawan1 OR ripcourtney OR dogs OR makeachange OR rude OR itdoesnotmakeyoucool OR tomyfutureson OR tuite10pessoasbonitas OR tvo OR debate2012 OR sex OR pets OR p2b OR hot OR justsayin OR fuckyou OR  suck OR rude OR black OR pussy OR sex OR negro OR puppy OR  LGBTQ OR  hypocrites OR  honesty  OR Whore OR dog OR france) python lang:en until:2023-03-03 since:2015-01-01" 
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query1).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query1.csv')
# Out:
# <ipython-input-46-1774cfb05d85>:8: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-46-1774cfb05d85>:8: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])

# %%
query2 = "( share OR obese OR standup OR debates OR savealife OR bully OR bullies OR istopbullying OR brave OR in8thgrade OR bullyingisforlosers OR stopbullying OR bullyingé OR impactlive OR glee OR anonymous OR tcot OR mentionke OR banbeliebers) python lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query2).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query2.csv')
# Out:
# <ipython-input-48-a6c840d591e0>:8: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-48-a6c840d591e0>:8: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])

# %%
query3 = "(auspol OR saynotobullying OR dt OR bullymovie OR education OR moms OR eating OR hypocrite OR pathetic OR spiritday OR uk OR edchat OR r OR nobodylikes OR neverwouldiever OR ripamandatodd) python lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query3).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query3.csv')
# Out:
# <ipython-input-49-7b7a941cbe4b>:8: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-49-7b7a941cbe4b>:8: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])

# %%
query4 = "( greysonfact OR lgbt OR cyberbullyingiswrong OR cdnpoli OR bornbravebus OR 30thingsaboutme OR karma OR bullied OR ripdemizadirectioner OR wheniwaslittle OR childabuse OR s OR whydoyouthinkitsokayto OR teamfollowback OR 1dfact OR gop OR sorrynotsorry) python lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query4).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query4.csv')
# Out:
# <ipython-input-50-567721f4585b>:8: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-50-567721f4585b>:8: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])

# %%
query5 = "( xfactor OR obesity OR ripamanda OR no OR pitbull OR pinkshirtday OR gangupforgood OR health OR sad OR wwe OR fridayfightagainst OR mean OR ff OR amandatodd OR school OR bullyingisnothot OR bgc9 OR iwanttopunchpeoplewho OR antibullying OR growup) python lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query5).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query5.csv')
# Out:
# <ipython-input-51-bc1fcc089f97>:8: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-51-bc1fcc089f97>:8: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])

# %%
query6 = "(ripmegan OR stopbullyingnow OR ripboybeliebermartin OR capricorn OR suicide OR itsnotokayto OR schools OR 100thingsihate OR rt OR ifihadthepower OR truth OR nw OR porn OR englishbulldog OR libra OR kids OR twitition OR dads OR wtf OR típicodegordos) python lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 5000
for tweet in sntwitter.TwitterSearchScraper(query6).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/query6.csv')
# Out:
# <ipython-input-52-ef402119c906>:8: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-52-ef402119c906>:8: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])

# %% [markdown]
# # **Non B**

# %%
query = "python lang:en until:2023-03-03 since:2015-01-01"
tweets = []
limit = 20000
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])    
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv('/content/drive/MyDrive/Dataset/tweetData.csv')
# Out:
# <ipython-input-53-944a86d96375>:8: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-53-944a86d96375>:8: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])

# %% [markdown]
# # **combined**

# %%
query1 = pd.read_csv('/content/drive/MyDrive/Dataset/query1.csv')
query2 = pd.read_csv('/content/drive/MyDrive/Dataset/query2.csv')

# %%
query12 = pd.concat([query1,query2], axis = 0)

# %%
query3 = pd.read_csv('/content/drive/MyDrive/Dataset/query3.csv')
query4 = pd.read_csv('/content/drive/MyDrive/Dataset/query4.csv')

# %%
query34 = pd.concat([query3,query4], axis = 0)

# %%
query5 = pd.read_csv('/content/drive/MyDrive/Dataset/query5.csv')
query6 = pd.read_csv('/content/drive/MyDrive/Dataset/query6.csv')

# %%
query56 = pd.concat([query5,query6], axis = 0)

# %%
query1234 = pd.concat([query12,query34], axis = 0)

# %%
query123456 = pd.concat([query1234,query56], axis = 0)

# %%
cyberbullyingalldata  = query123456.loc[:, ~query123456.columns.str.contains('^Unnamed')]
cyberbullyingalldata.to_csv('/content/drive/MyDrive/Dataset/cyberbullyingalldata.csv')

# %%
data1 = pd.read_csv('/content/drive/MyDrive/Dataset/cyberbullyingalldata.csv')
data1.tail(5)
# Out:
#        Unnamed: 0                       Date          User  \
# 29995        4995  2022-12-02 11:10:48+00:00   JodieSpinka
# 29996        4996  2022-12-02 11:02:56+00:00  configuroweb
# 29997        4997  2022-12-02 10:51:54+00:00   LisaBegusch
# 29998        4998  2022-12-02 10:00:00+00:00   WRBookHouse
# 29999        4999  2022-12-02 09:56:53+00:00  manpreethere
#
#                                                    Tweet
# 29995  Python Coding For Kids: The Complete Python Ga...
# 29996  RT @OnlyDevs_: 7 Things Every  Newbie Web Deve...
# 29997  Happy Friday truth seekers, Solution Architect...
# 29998  Games and activities that teach kids ages 10+ ...
# 29999  RT TheTechPlatform "#LearnProgramming #webdesi...

# %%
data1.shape
# Out:
# (30000, 4)

# %%
data2 = pd.read_csv('/content/drive/MyDrive/Dataset/tweetData.csv')
data2.tail(5)
# Out:
#        Unnamed: 0                       Date             User  \
# 19995       19995  2023-02-27 14:23:01+00:00     ML_Jobs_Feed
# 19996       19996  2023-02-27 14:23:01+00:00     ML_Jobs_Feed
# 19997       19997  2023-02-27 14:22:37+00:00  SWChrisCreative
# 19998       19998  2023-02-27 14:22:19+00:00    KillingPython
# 19999       19999  2023-02-27 14:22:02+00:00      python_1111
#
#                                                    Tweet
# 19995  JPMorgan Chase &amp; Co. is looking for a Vice...
# 19996  Reddit is looking for a Senior Software Engine...
# 19997          Monty Python in the age of the Internet 😂
# 19998  🤣🤣while the real City boy is in Agulu doing re...
# 19999  This election was fixed from the start. Peter ...

# %%
data2.shape
# Out:
# (20000, 4)
